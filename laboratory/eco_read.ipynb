# %%
import pandas as pd

# %%
eco_data = pd.read_csv('data/economic_data.csv')
# Out:
#                             date                                      title  \
# 0      23-01-2013 09:30:00 +0000                        Total Vehicle Sales
# 1      23-01-2013 09:30:00 +0000                        Total Vehicle Sales
# 2      15-03-2013 13:55:00 +0000  Reuters/Michigan Consumer Sentiment Index
# 3      15-03-2013 13:15:00 +0000                  Industrial Production MoM
# 4      15-03-2013 13:15:00 +0000                       Capacity Utilization
# ...                          ...                                        ...
# 61647  24-04-2023 13:30:00 +0100                New Housing Price Index YoY
# 61648  24-04-2023 13:30:00 +0100                New Housing Price Index MoM
# 61649  24-04-2023 09:00:00 +0100                     Ifo Current Conditions
# 61650  24-04-2023 09:00:00 +0100                           Ifo Expectations
# 61651  24-04-2023 09:00:00 +0100                       Ifo Business Climate
#
#       country               indicator  \
# ...

# %%
eco_data.title.value_counts()
# Out:
# title
# Balance of Trade                       1219
# Unemployment Rate                      1051
# Retail Sales YoY                       1012
# Retail Sales MoM                        910
# Inflation Rate YoY                      851
#                                        ...
# Gdp Growth Annualized Final               1
# Real Consumer Spending                    1
# Inflation Rate Ex-Fresh Food YoY          1
# Private New Capital Expenditure QoQ       1
# ANZ-Indeed Job Ads MoM                    1
# Name: count, Length: 1089, dtype: int64

# %%
eco_data.indicator.value_counts()
# Out:
# indicator
# Calendar                        3845
# Manufacturing PMI               1606
# Inflation Rate                  1298
# Services PMI                    1254
# Balance of Trade                1219
#                                 ...
# Industrial Profits                 2
# Industry Index Construction        2
# Industry Index Manufacturing       2
# Employed Persons                   1
# GDP Growth Annualized              1
# Name: count, Length: 328, dtype: int64

# %%
eco_data.importance.value_counts()
# Out:
# importance
# -1    30556
#  0    26669
#  1     4427
# Name: count, dtype: int64
